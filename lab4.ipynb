# %% [markdown]
# # Лабораторная работа 4.
# # Сетевые алгоритмы. Методы поиска.

# %% [markdown]
# ## Выполнил студент группы БФИ2202 Плешаков Александр Сергеевич
# ***

# %% [markdown]
# ### Задание
#
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.
#
# 1.  Бинарный поиск | Бинарное дерево | Фибоначчиев | Интерполяционный
#
# 2.  Простое рехэширование | Рехэширование с помощью псевдослучайных чисел | Метод цепочек
#
# 3.  Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки, расположенные по вертикалям, горизонталям и обеим диагоналям
# Написать программу,  которая находит хотя бы один способ решения задач.

# %% [markdown]
# ### Выполнение:

# %%
import random
import time


def generate_array(count):
   array = [int(random.randint(-999, 1000)) for i in range(count)]
   return array
# Out:
# [-319, 926, 89, -877, 925, -151, 814, 803, 69, 598, 396, -4, 976, -861, 653, 428, -152, -580, 114, -596, -999, -464, 27, 943, 39, -587, 529, 207, 801, -240, 801, 67, -538, 516, -397, 489, 141, 2, -395, 848, -892, 605, 867, -298, 28, -325, -930, -959, 272, 362, -844, -223, -111, -346, -74, 91, -431, 554, 462, 661, 1000, -269, 428, -402, 678, -317, -343, 415, 572, 4, 353, 762, -141, -78, -956, 567, 298, 504, 766, 49, 541, -634, 17, -298, -359, 39, 893, 244, 903, 594, -953, -251, -69, -550, 933, 659, -8, -388, 846, -941]

# %% [markdown]
# ***
# ### Бинарный поиск

# %%
generated_array = generate_array(20)
generated_array.sort()
print(generated_array)

def binary_search(arr, target):
    left = 0
    right = len(arr) - 1

    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid  
        elif arr[mid] < target:
            left = mid + 1  
        else:
            right = mid - 1  

    return -1  
target = int(input())
start_time = time.time()
result = binary_search(generated_array, target)
print("--- {0} ms ---".format(time.time() - start_time), "Бинарный поиск")
if result != -1:
    print("Элемент", target, "найден по индексу", result)
else:
    print("Элемент", target, "не найден в массиве")
# Out:
# [-934, -928, -885, -695, -592, -457, -422, -129, 117, 188, 244, 261, 344, 352, 381, 605, 689, 908, 909, 965]
# --- 5.888938903808594e-05 ms --- Бинарный поиск
# Элемент 689 найден по индексу 16

# %% [markdown]
# ***
# ### Бинарное дерево поиска

# %% [markdown]
# ### Вывод
